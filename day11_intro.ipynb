# %% [markdown]
# # Introduction to Jupyter

# %% [markdown]
# ## Second Heading

# %%
a = 10
b = 25
c = a+b
print(c)
# Out:
# 35

# %% [markdown]
# ### this is something

# %% [markdown]
# <i style="color:red;">this is simple markdown</i><br>
# <img src = "https://miro.medium.com/max/367/1*1lXiy9OzjFbLMA4-VbDwvQ.png">

# %%
d = c*3
print(d)
# Out:
# 90

# %%
for i in range(1000):
    print('bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi')
# Out:
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# bahut saari bakwass aati hi jaegi or pata nahi kab tak aaegi
# ...

# %%
a = input('enter the name: ')
# Out:
# ---------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-22-dc4d2d330e71> in <module>
# ----> 1 a = input('enter the name: ')
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
# ...

# %%
print(4-5)
# Out:
# -1
